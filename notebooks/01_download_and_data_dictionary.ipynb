# %% [markdown]
# # Download instructions and data dictionary
#
# This notebook is part of PsySuccess AI. Run the pipeline scripts first, then use this notebook for inspection and reporting.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

PROJECT_ROOT = Path('..').resolve()
PROJECT_ROOT
